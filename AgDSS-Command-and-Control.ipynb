# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = np.load('media-root/labels/root/pAbSSjBp/labels/tile_4000_22000_20_20.npy')
plt.imshow(a[0])
plt.imsave('name.png', a[0])

# %%
import matplotlib.image as mpimg
img = mpimg.imread('media-root/labels/root/pAbSSjBp/images/tile_4000_22000_20_20.png')
imgplot = plt.imshow(img)

# %%
from PIL import Image

import numpy as np

img = Image.open("name.png")

background = Image.open("media-root/labels/root/pAbSSjBp/images/tile_4000_22000_20_20.png")

background.paste(img, (0, 0), background)
background.save('superimpose.png',"PNG")

# %%
img = mpimg.imread('superimpose.png')
imgplot = plt.imshow(img)

# %%
# Old code

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from webclient.image_ops import search as data
from webclient.image_ops import convert_images as ci
import matplotlib.pyplot as plt

# %%
parentCrop, labelMask = data.trainingsPatchForLabel(ImageLabel.objects.last())

# %%
type(parentCrop)

# %%
plt.subplot(1,3,1)
plt.imshow(parentCrop)
plt.subplot(1,3,2)
plt.imshow(labelMask)
plt.subplot(1,3,3)
plt.imshow(parentCrop)
plt.hold
plt.imshow(labelMask*10+parentCrop[:,:,0])
